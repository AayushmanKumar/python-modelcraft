# %% [markdown]
# <a href="https://colab.research.google.com/github/AayushmanKumar/python-modelcraft/blob/main/food_coded_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Aayushman Kumar
# Roll: 230029

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("food_coded.csv")

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
df.shape
# Out:
# (125, 61)

# %%
df.describe(include='all')
# Out:
#         GPA      Gender   breakfast  calories_chicken  calories_day  \
# count   123  125.000000  125.000000        125.000000    106.000000
# unique   38         NaN         NaN               NaN           NaN
# top     3.5         NaN         NaN               NaN           NaN
# freq     13         NaN         NaN               NaN           NaN
# mean    NaN    1.392000    1.112000        577.320000      3.028302
# std     NaN    0.490161    0.316636        131.214156      0.639308
# min     NaN    1.000000    1.000000        265.000000      2.000000
# 25%     NaN    1.000000    1.000000        430.000000      3.000000
# 50%     NaN    1.000000    1.000000        610.000000      3.000000
# 75%     NaN    2.000000    1.000000        720.000000      3.000000
# max     NaN    2.000000    2.000000        720.000000      4.000000
#
#         calories_scone     coffee comfort_food comfort_food_reasons  \
# count       124.000000  125.00000          124                  123
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df.replace(np.nan,'0',inplace = True)

df.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64

# %%
df['GPA'].unique()
# Out:
# array(['2.4', '3.654', '3.3', '3.2', '3.5', '2.25', '3.8', '3.904', '3.4',
#        '3.6', '3.1', nan, '4', '2.2', '3.87', '3.7', '3.9', '2.8', '3',
#        '3.65', '3.89', '2.9', '3.605', '3.83', '3.292', '3.35',
#        'Personal ', '2.6', '3.67', '3.73', '3.79 bitch', '2.71', '3.68',
#        '3.75', '3.92', 'Unknown', '3.77', '3.63', '3.882'], dtype=object)

# %%
df['GPA'] = pd.to_numeric(df['GPA'], errors='coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')

# %%
df.replace(np.nan,'0',inplace = True)

# %%
df['GPA'].unique()
# Out:
# array([2.4, 3.654, 3.3, 3.2, 3.5, 2.25, 3.8, 3.904, 3.4, 3.6, 3.1, '0',
#        4.0, 2.2, 3.87, 3.7, 3.9, 2.8, 3.0, 3.65, 3.89, 2.9, 3.605, 3.83,
#        3.292, 3.35, 2.6, 3.67, 3.73, 2.71, 3.68, 3.75, 3.92, 3.77, 3.63,
#        3.882], dtype=object)

# %%
df['weight'].unique()
# Out:
# array([187.0, 155.0, '0', 190.0, 180.0, 137.0, 125.0, 116.0, 110.0, 264.0,
#        123.0, 185.0, 145.0, 170.0, 135.0, 165.0, 175.0, 195.0, 105.0,
#        160.0, 167.0, 115.0, 205.0, 128.0, 150.0, 140.0, 120.0, 100.0,
#        113.0, 168.0, 169.0, 200.0, 265.0, 192.0, 118.0, 210.0, 112.0,
#        130.0, 127.0, 129.0, 260.0, 184.0, 230.0, 138.0, 156.0],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    object
#  5   calories_scone                125 non-null    object
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    object
#  8   comfort_food_reasons          125 non-null    object
#  9   comfort_food_reasons_coded    125 non-null    object
#  10  cook                          125 non-null    object
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df['GPA'] = df['GPA'].astype(float)
df['weight'] = df['weight'].astype(float)

# %%
df[['GPA']].boxplot()
# Out:
# <Axes: >

# %%
df[['weight']].boxplot()
# Out:
# <Axes: >

# %%
df['Gender'].unique()
# Out:
# array([2, 1])

# %%
from sklearn.preprocessing import LabelEncoder # OneHotEncoding, Scaling & normalization, Splitting test/train data

le = LabelEncoder()
df['ideal_diet_coded'] = le.fit_transform(df['ideal_diet'])

# Create a mapping dictionary
encoding_mapping = dict(zip(df['ideal_diet_coded'].unique(), df['ideal_diet'].unique()))

# Display the mapping
print("Mapping between Original Values and Encoded Values:")
for original_value, encoded_value in encoding_mapping.items():
    print(f"{original_value}: {encoded_value}")
# Out:
# Mapping between Original Values and Encoded Values:
# 113: being healthy
# 106: Try to eat 5-6 small meals a day. While trying to properly distribute carbs, protein, fruits, veggies, and dairy.
# 118: i would say my ideal diet is my current diet
# 25: Healthy, fresh veggies/fruits & organic foods
# 49: Ideally I would like to be able to eat healthier foods in order to loose weight.
# 72: My ideal diet is to eat 3 times a day including breakfast on time. Eat healthy food.
# 39: I would ideally like to eat more fresh fruits and vegetables. However, its difficult to get to the store all the time to buy fresh.
# 67: My ideal diet is filled with a lot of fruit and chicken. I also really enjoy eggs any type of way with toast.
# 101: The same as it is now.
# 55: Lots of protein, carbs, and fruits and veggies.
# 13: Chicken, fish
# 59: More healthy varienty.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    float64
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    object
#  5   calories_scone                125 non-null    object
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    object
#  8   comfort_food_reasons          125 non-null    object
#  9   comfort_food_reasons_coded    125 non-null    object
#  10  cook                          125 non-null    object
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df.drop(col, inplace=True, axis=1)

# %%
df.corr()
# Out:
#                                    GPA    Gender  breakfast  calories_chicken  \
# GPA                           1.000000 -0.038645  -0.071659          0.010324
# Gender                       -0.038645  1.000000   0.130527         -0.098265
# breakfast                    -0.071659  0.130527   1.000000         -0.029597
# calories_chicken              0.010324 -0.098265  -0.029597          1.000000
# coffee                       -0.109346 -0.032178  -0.089756          0.159031
# comfort_food_reasons_coded.1 -0.067287  0.209109   0.018233         -0.009311
# diet_current_coded           -0.046111  0.145155   0.111687         -0.148827
# eating_changes_coded         -0.140359  0.037723   0.151237          0.040957
# eating_changes_coded1        -0.055387  0.006148   0.062699          0.083102
# eating_out                   -0.096327  0.008091  -0.018787          0.024428
# ethnic_food                   0.155575 -0.146148  -0.290289          0.090029
# ...

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  coffee  \
# 0  2.400       2          1               430       1
# 1  3.654       1          1               610       2
# 2  3.300       1          1               720       2
# 3  3.200       1          1               430       2
# 4  3.500       1          1               720       2
#
#    comfort_food_reasons_coded.1  diet_current_coded  eating_changes_coded  \
# 0                             9                   1                     1
# 1                             1                   2                     1
# 2                             1                   3                     1
# 3                             2                   2                     1
# 4                             1                   2                     3
#
#    eating_changes_coded1  eating_out  ...  italian_food  nutritional_check  \
# 0                      1           3  ...             5                  5
# ...

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'coffee',
#        'comfort_food_reasons_coded.1', 'diet_current_coded',
#        'eating_changes_coded', 'eating_changes_coded1', 'eating_out',
#        'ethnic_food', 'fav_cuisine_coded', 'fries', 'fruit_day', 'grade_level',
#        'greek_food', 'healthy_feeling', 'ideal_diet_coded', 'indian_food',
#        'italian_food', 'nutritional_check', 'parents_cook', 'pay_meal_out',
#        'thai_food', 'turkey_calories', 'veggies_day', 'vitamins',
#        'waffle_calories', 'weight'],
#       dtype='object')

# %%
df.drop(columns=['breakfast', 'calories_chicken', 'comfort_food_reasons_coded.1', 'diet_current_coded',
       'eating_changes_coded', 'eating_changes_coded1','fav_cuisine_coded', 'fries', 'fruit_day', 'greek_food','ideal_diet_coded', 'indian_food',
       'italian_food', 'nutritional_check', 'parents_cook', 'pay_meal_out',
       'thai_food', 'turkey_calories', 'veggies_day', 'vitamins',
       'waffle_calories' ],inplace=True,axis=1)

# %%
df.head()
# Out:
#      GPA  Gender  coffee  eating_out  ethnic_food  grade_level  \
# 0  2.400       2       1           3            1            2
# 1  3.654       1       2           2            4            4
# 2  3.300       1       2           2            5            3
# 3  3.200       1       2           2            5            4
# 4  3.500       1       2           2            4            4
#
#    healthy_feeling  weight
# 0                2   187.0
# 1                5   155.0
# 2                6     0.0
# 3                7     0.0
# 4                6   190.0

# %%
correlation = df.corr()
plt.figure(figsize=(8, 8))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Name: Aayushman Kumar
# Roll: 230029
